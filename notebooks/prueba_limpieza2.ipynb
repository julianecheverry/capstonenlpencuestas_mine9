# %% [markdown]
# # Prueba del módulo `limpieza.py`
# Este notebook prueba las clases `dataloader` y `cleaner` del script `limpieza.py` utilizando un archivo Excel ubicado en `data/raw/`.

# %% [markdown]
# ## 0. Configuración de rutas

# %%
import sys
from pathlib import Path

# Agregar la carpeta 'src' al path para importar limpieza.py
ruta_src = Path('..') / 'src'
sys.path.append(str(ruta_src))

# Ruta al archivo Excel de prueba
RUTA_ARCHIVO = Path('..') / 'data' / 'raw' / 'Consolidado Histórico Evaluación Docente Anonimizado.xlsx'  # <- Ajustar al nombre real del archivo
COLUMNA_CLAVE = 'Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico'                                      # <- Ajustar al nombre real de la columna
HOJA = 0                                                     # <- Índice o nombre de la hoja Excel
RUTA_SALIDA = Path('..') / 'data' / 'processed' / 'datos_limpios_obs20.csv'

print(f"Ruta archivo : {RUTA_ARCHIVO.resolve()}")
print(f"Archivo existe: {RUTA_ARCHIVO.exists()}")
# Out:
# Ruta archivo : C:\Users\HP ENVY\Documents\Maestria_MINE\SEMESTRE 4\3.OpcionGrado--Wilmer\capstonenlpencuestas_mine9\data\raw\Consolidado Histórico Evaluación Docente Anonimizado.xlsx
# Archivo existe: True

# %% [markdown]
# ## 1. Importar módulo

# %%
# importar las clases desde el .py
from datacleaning.limpieza import Cleaner

print("Módulo importado correctamente.")
# Out:
# Módulo importado correctamente.

# %% [markdown]
# ## 2. Prueba de `dataloader` — carga del archivo Excel

# %% [markdown]
# ## 2.1. Prueba carga - sin recurrir a la clase
#
# > Verificar cómo reconoce Pandas la columna clave

# %%
import pandas as pd

df_prueba1 = pd.read_excel(RUTA_ARCHIVO, sheet_name=HOJA)
df_prueba1.info()  # Mostrar información del DataFrame antes de la limpieza

# %%
df_prueba1.columns

# %%
print(f"DEBUG: El dtype es: {df_prueba1[COLUMNA_CLAVE].dtype}")
print(f"DEBUG: Los primeros 5 valores son: {df_prueba1[COLUMNA_CLAVE].head().tolist()}")

# %% [markdown]
# ## 2.2. Prueba de carga con la clase `Cleaner`

# %%
cleaner = Cleaner(
    file_path=RUTA_ARCHIVO,
    survey_name="stopwords_evaluaciondocente", #Calidad Docentes
    key_column=COLUMNA_CLAVE,
    sheet_name=HOJA
)

df = cleaner.load_data()

print(f"Filas: {df.shape[0]} | Columnas: {df.shape[1]}")
print(f"Columnas disponibles: {df.columns.tolist()}")
df.head()
# Out:
# Filas: 64697 | Columnas: 76
# Columnas disponibles: ['Periodo', 'Nivel', 'ID de respuesta', 'Marca de tiempo (mm/dd/yyyy)', 'Tiempo necesario para completar (segundos)', 'Codigo del Grupo', 'Grupo', 'Materia', 'Codigo Materia', 'Facultad Estudiante', 'EVALUACIÓN GENERALEn una escala de 1 a 5, en la que 1 es POCO SATISFECHO y 5 es MUY SATISFECHO, valore: - 1. Su satisfacción general con el desempeño del(la) profesor(a) del espacio académico', "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 2. Realiza seguimiento al avance de resultados de aprendizajes y cumple con el programa de clase (temas metodología, evaluación)", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 3. Demuestra dominio y experiencia sobre los temas desarrollados en el espacio académico", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 4. Explica de forma clara y precisa los temas del espacio académico", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 5. Utiliza diversas estrategias de enseñanza para que los(as) estudiantes alcancen los resultados de aprendizaje esperados", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 6. Aclara, de manera suficiente y precisa, las dudas e inquietudes que surgen en el desarrollo del espacio académico", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 7. Incentiva el compromiso de los(as) estudiantes con su proceso de aprendizaje", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 8. Propicia un trato respetuoso con y entre los estudiantes, promoviendo la sana convivencia y la equidad", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos relacionados con el desempeño de su profesor(a): - 9. Utiliza recursos didácticos (material bibliográfico, lecturas, videos, podcast, etc.) que facilitan el aprendizaje", "ASPECTOS PEDAGÓGICOS, DIDÁCTICOS Y ACADÉMICOS\xa0En una escala de 1 a 5, en la que 1 es 'Totalmente en desacuerdo', 2 es 'En desacuerdo', 3 es 'Ni de acuerdo ni en desacuerdo', 4 es 'De acuerdo' y 5 es 'Totalmente de acuerdo', valore los siguientes aspectos ...
#   Periodo     Nivel  ID de respuesta Marca de tiempo (mm/dd/yyyy)  \
# 0  2025-2  Pregrado        190799007          2025-10-03 13:47:15
# 1  2025-2  Pregrado        194717474          2025-11-06 09:07:13
# 2  2025-2  Pregrado        190799134          2025-10-03 13:48:26
# 3  2025-2  Pregrado        190799146          2025-10-03 13:48:31
# 4  2025-2  Pregrado        190799156          2025-10-03 13:48:36
#
#    Tiempo necesario para completar (segundos) Codigo del Grupo  \
# 0                                        45.0             001Z
# 1                                        20.0             001Z
# 2                                        84.0             001Z
# 3                                        45.0          GRUPO 1
# 4                                        66.0             001Z
#
#                                       Grupo                Materia  \
# 0          IE ENFOQUES VERDES Y SOSTENIBLES        CURSO LIBRE III
# 1               IE ARME SU CALENTADOR SOLAR         CURSO LIBRE VI
# 2    IE HERRAMIENTAS DIGITALES NO DISENADOR  INTERDISCIPLINARIOS 1
# 3  IE TODO SOBRE EL AMOR: CLAVES PARA CONST  INTERDISCIPLINARIOS 1
# 4          IE ENFOQUES VERDES Y SOSTENIBLES  INTERDISCIPLINARIOS 1
#
#   Codigo Materia                                Facultad Estudiante  ...  \
# 0         CM0787         FACULTAD DE COMUNICACION SOCIAL PERIODISMO  ...
# 1         CM0811         FACULTAD DE COMUNICACION SOCIAL PERIODISMO  ...
# 2         AH0040  FACULTAD DE ADMINISTRACION DE EMPRESAS TURISTI...  ...
# 3         AH0040  FACULTAD DE ADMINISTRACION DE EMPRESAS TURISTI...  ...
# 4         AH0040  FACULTAD DE ADMINISTRACION DE EMPRESAS TURISTI...  ...
#
#   Promedio Autoevaluación - Componente2 Promedio Autoevaluación - Componente3  \
# 0                              4.666667                                     5
# 1                                     5                                   4.4
# 2                                     5                                   4.4
# 3                                     5                                     5
# 4                              4.666667                                     5
#
#   Promedio Autoevaluación - Componente4 Promedio Autoevaluación - Componente5  \
# 0                                     5                                     5
# 1                                   4.5                                     5
# 2                                   4.5                                     4
# 3                                   4.5                                     5
# 4                                     5                                     5
#
#   Promedio Autoevaluación - General  \
# 0                          4.952381
# 1                          4.619048
# 2                          4.666667
# 3                          4.904762
# 4                          4.952381
#
#                           Facultad de oferta Evaluación Autoevaluación  \
# 0  INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 1  INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 2  INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 3  INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 4  INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
#
#   Id Estudiante Id Docente
# 0             1          1
# 1             2          2
# 2             3          3
# 3             4          4
# 4             5          1
#
# [5 rows x 76 columns]

# %% [markdown]
# ## 3. Prueba de `cleaner.limpiar_texto` — limpieza unitaria

# %%
# Casos de prueba individuales
casos = [
    "  ¡Hola Mundo!  ",
    "Ángela estudió en la Universidad Académica",
    "Texto con: caracteres@especiales #raros!",
    "España y la ñ deben conservarse",
]

print(f"{'Texto original':<45} -> {'Texto limpio'}")
print("-" * 75)
for caso in casos:
    print(f"{repr(caso):<45} -> {repr(cleaner._clean_text(caso))}")

# %% [markdown]
# ## 4. Prueba de `cleaner.limpiar_columna_clave` — limpieza sobre el DataFrame

# %%
df_limpio = cleaner.clean_key_column()

print(f"Columna nueva generada: '{COLUMNA_CLAVE}_clean'")
df_limpio[[COLUMNA_CLAVE, f"{COLUMNA_CLAVE}_clean"]].head(10)
# Out:
# Columna nueva generada: 'Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico_clean'
#   Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico  \
# 0                                                 NR
# 1                                                 NR
# 2                                                 NR
# 3                                                 NR
# 4                                           Ninguno.
# 5                                 que siga mejorando
# 6                                                 NR
# 7                                                 NR
# 8                                                 NR
# 9                                                 NR
#
#   Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico_clean
# 0                                                 nr
# 1                                                 nr
# 2                                                 nr
# 3                                                 nr
# 4                                            ninguno
# 5                                 que siga mejorando
# 6                                                 nr
# 7                                                 nr
# 8                                                 nr
# 9                                                 nr

# %%
df_sinstopwords = cleaner.eliminate_stopwords()

print(f"Columna nueva generada: '{COLUMNA_CLAVE}_no_stopwords'")
print(f"Columna nueva generada: '{COLUMNA_CLAVE}_no_stopwords_no_adverbs'")
# Out:
# Columna nueva generada: 'Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico_no_stopwords'
# Columna nueva generada: 'Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico_no_stopwords_no_adverbs'

# %% [markdown]
# ## 5. Prueba de `cleaner.save_cleaned_data` — exportar a CSV

# %%
# Crear carpeta de salida si no existe
RUTA_SALIDA.parent.mkdir(parents=True, exist_ok=True)

cleaner.save_cleaned_data(out_path=str(RUTA_SALIDA))

print(f"Archivo guardado en: {RUTA_SALIDA.resolve()}")
# Out:
# clean data saved in '..\data\processed\datos_limpios_obs20.csv'.
# Archivo guardado en: C:\Users\HP ENVY\Documents\Maestria_MINE\SEMESTRE 4\3.OpcionGrado--Wilmer\capstonenlpencuestas_mine9\data\processed\datos_limpios_obs20.csv

# %%
import pandas as pd
datos_sinstops = pd.read_csv(RUTA_SALIDA)
# Out:
# C:\Users\HP ENVY\AppData\Local\Temp\ipykernel_3788\4191372400.py:2: DtypeWarning: Columns (0: Observaciones eval, 1: Observaciones Auto) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_sinstops = pd.read_csv(RUTA_SALIDA)

# %% [markdown]
# ### 5.1. Verificar columnas creadas

# %%
datos_sinstops
# Out:
#       Periodo     Nivel  ID de respuesta Marca de tiempo (mm/dd/yyyy)  \
# 0      2025-2  Pregrado        190799007          2025-10-03 13:47:15
# 1      2025-2  Pregrado        194717474          2025-11-06 09:07:13
# 2      2025-2  Pregrado        190799134          2025-10-03 13:48:26
# 3      2025-2  Pregrado        190799146          2025-10-03 13:48:31
# 4      2025-2  Pregrado        190799156          2025-10-03 13:48:36
# ...       ...       ...              ...                          ...
# 64692  2026-1  Pregrado               56                          NaN
# 64693  2026-1  Pregrado               58                          NaN
# 64694  2026-1  Pregrado               63                          NaN
# 64695  2026-1  Pregrado               64                          NaN
# 64696  2026-1  Pregrado               65                          NaN
#
#        Tiempo necesario para completar (segundos) Codigo del Grupo  \
# 0                                            45.0             001Z
# 1                                            20.0             001Z
# 2                                            84.0             001Z
# 3                                            45.0          GRUPO 1
# 4                                            66.0             001Z
# ...                                           ...              ...
# 64692                                         NaN             001Z
# 64693                                         NaN             001Z
# 64694                                         NaN             001Z
# 64695                                         NaN          Grupo 2
# 64696                                         NaN             001Z
#
#                                           Grupo                Materia  \
# 0              IE ENFOQUES VERDES Y SOSTENIBLES        CURSO LIBRE III
# 1                   IE ARME SU CALENTADOR SOLAR         CURSO LIBRE VI
# 2        IE HERRAMIENTAS DIGITALES NO DISENADOR  INTERDISCIPLINARIOS 1
# 3      IE TODO SOBRE EL AMOR: CLAVES PARA CONST  INTERDISCIPLINARIOS 1
# 4              IE ENFOQUES VERDES Y SOSTENIBLES  INTERDISCIPLINARIOS 1
# ...                                         ...                    ...
# 64692            EL EXTRANO MUNDO DE TIM BURTON              IDIOMA VI
# 64693                 IE RECORRIDOS CAPITALINOS             ELECTIVA I
# 64694              IE DE BOLIVAR AL CHE GUEVARA               IDIOMA 3
# 64695     IE INTELIGENCIA EMOCIONAL VIDA DIARIA               IDIOMA 1
# 64696               IE ARME SU CALENTADOR SOLAR               IDIOMA 3
#
#       Codigo Materia                                Facultad Estudiante  ...  \
# 0             CM0787         FACULTAD DE COMUNICACION SOCIAL PERIODISMO  ...
# 1             CM0811         FACULTAD DE COMUNICACION SOCIAL PERIODISMO  ...
# 2             AH0040  FACULTAD DE ADMINISTRACION DE EMPRESAS TURISTI...  ...
# 3             AH0040  FACULTAD DE ADMINISTRACION DE EMPRESAS TURISTI...  ...
# 4             AH0040  FACULTAD DE ADMINISTRACION DE EMPRESAS TURISTI...  ...
# ...              ...                                                ...  ...
# 64692         EC1139                               FACULTAD DE ECONOMIA  ...
# 64693         RE0730        FACULTAD DE ESTUDIOS DEL PATRMONIO CULTURAL  ...
# 64694         MA0120                        DEPARTAMENTO DE MATEMÁTICAS  ...
# 64695         MA0105                        DEPARTAMENTO DE MATEMÁTICAS  ...
# 64696         MA0120                        DEPARTAMENTO DE MATEMÁTICAS  ...
#
#       Promedio Autoevaluación - Componente5 Promedio Autoevaluación - General  \
# 0                                         5                4.9523809523809526
# 1                                         5                 4.619047619047619
# 2                                         4                 4.666666666666667
# 3                                         5                 4.904761904761905
# 4                                         5                4.9523809523809526
# ...                                     ...                               ...
# 64692                                     4                 4.428571428571429
# 64693                                     5                 4.523809523809524
# 64694                                     5                 4.761904761904762
# 64695                                     5                 4.571428571428571
# 64696                                     5                 4.619047619047619
#
#                                 Facultad de oferta Evaluación Autoevaluación  \
# 0        INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 1        INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 2        INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 3        INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# 4        INSTITUTO DE ESTUDIOS INTERDISCIPLINARIOS         Si             Si
# ...                                            ...        ...            ...
# 64692                         FACULTAD DE ECONOMIA         No             Si
# 64693  FACULTAD DE ESTUDIOS DEL PATRMONIO CULTURAL         No             Si
# 64694                  DEPARTAMENTO DE MATEMÁTICAS         No             Si
# 64695                  DEPARTAMENTO DE MATEMÁTICAS         No             Si
# 64696                  DEPARTAMENTO DE MATEMÁTICAS         No             Si
#
#       Id Estudiante Id Docente  \
# 0                 1          1
# 1                 2          2
# 2                 3          3
# 3                 4          4
# 4                 5          1
# ...             ...        ...
# 64692             0          9
# 64693             0       1186
# 64694             0          8
# 64695             0          6
# 64696             0          2
#
#       Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico_clean  \
# 0                                                     nr
# 1                                                     nr
# 2                                                     nr
# 3                                                     nr
# 4                                                ninguno
# ...                                                  ...
# 64692                                                 nr
# 64693                                                 nr
# 64694                                                 nr
# 64695                                                 nr
# 64696                                                 nr
#
#       Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico_no_stopwords  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64692                                                NaN
# 64693                                                NaN
# 64694                                                NaN
# 64695                                                NaN
# 64696                                                NaN
#
#       Observaciones - 20. Oportunidades de mejora del docente y/o del espacio académico_no_stopwords_no_adverbs
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64692                                                NaN
# 64693                                                NaN
# 64694                                                NaN
# 64695                                                NaN
# 64696                                                NaN
#
# [64697 rows x 79 columns]

# %%
# datos_limpios.dropna(how='all').iloc[:, -3:].sort_values(by=datos_limpios.columns[-1])  # Mostrar las dos últimas columnas

# %% [markdown]
# ## 6. Prueba de manejo de errores

# %%
# 6.1 Archivo inexistente
print("--- Archivo inexistente ---")
try:
    loader_err = Cleaner(file_path='no_existe.xlsx', key_column=COLUMNA_CLAVE,
                         survey_name="stopwords_calidaddocentes", sheet_name=HOJA)
    loader_err.load_data()
except (FileNotFoundError, ValueError) as e:
    print(f"[OK] Error capturado: {e}")

# %%
# 6.2 Columna clave inexistente
print("\n--- Columna clave inexistente ---")
try:
    loader_err = Cleaner(file_path=RUTA_ARCHIVO, key_column='columna_falsa',
                    survey_name="stopwords_calidaddocentes", sheet_name=HOJA)

    loader_err.load_data()
except ValueError as e:
    print(f"[OK] Error capturado: {e}")

# %%
# 6.3 Formato no soportado
print("\n--- Formato no soportado ---")
try:
    loader_err = Cleaner(file_path='archivo.txt', key_column=COLUMNA_CLAVE,
                    survey_name="stopwords_calidaddocentes", sheet_name=HOJA)

    loader_err.load_data()
except (FileNotFoundError, ValueError) as e:
    print(f"[OK] Error capturado: {e}")

# %% [markdown]
# # 7. Prueba del módulo `synonyms.py`
# Este notebook prueba la clase `SynonymReplacer` del módulo `synonyms.py`, encargada de reemplazar términos por su sinónimo más común usando un modelo Word2Vec preentrenado en español (SBWCE) combinado con coloquialismos colombianos añadidos manualmente.

# %% [markdown]
# ## 7.0. Configuración e importación

# %%
# importar la clase desde el .py (misma carpeta que datacleaning.limpieza)
from datacleaning.synonyms import SynonymReplacer

print("Módulo importado correctamente.")

# %% [markdown]
# ## 7.1. Prueba de `load_model` — carga (y descarga si aplica) del modelo Word2Vec

# %%
# NOTA: si el modelo no existe en SYNONYMS_MODEL_PATH, esta celda lo
# descargará automáticamente (~2GB), por lo que puede tardar varios
# minutos la primera vez que se ejecute.
replacer = SynonymReplacer()

replacer.load_model()

print(f"Modelo cargado correctamente.")
print(f"Tamaño del vocabulario: {len(replacer.model.key_to_index)}")

# %% [markdown]
# ## 7.2. Prueba de `build_synonyms_dict` — autogeneración del diccionario de sinónimos

# %%
synonyms_dict = replacer.build_synonyms_dict()

print(f"Total de términos mapeados: {len(synonyms_dict)}")
print("Ejemplo de entradas generadas:")
for palabra, canonico in list(synonyms_dict.items())[:15]:
    print(f"  {palabra:<15} -> {canonico}")

# %%
# Verificación puntual: los coloquialismos colombianos deben estar
# presentes y apuntar al canónico esperado
for coloquial, esperado in replacer.colombian_colloquialisms.items():
    obtenido = synonyms_dict.get(coloquial)
    estado = "[OK]" if obtenido == esperado else "[FALLO]"
    print(f"{estado} '{coloquial}' -> '{obtenido}' (esperado: '{esperado}')")

# %% [markdown]
# ## 7.3. Prueba de `replace_synonyms` — casos unitarios

# %%
# Casos de prueba individuales
casos_sinonimos = [
    "el servicio fue maravilloso",
    "la comida estuvo terrible",
    "todo estuvo bacano y muy chevere",
    "EXCELENTE atencion, MUY BUENA",              # mayusculas
    "el profesor uso xilofono en la clase",         # palabra fuera de vocabulario
    "muy chimba la dinamica de la materia",
]

print(f"{'Texto original':<45} -> {'Texto con sinonimos reemplazados'}")
print("-" * 90)
for caso in casos_sinonimos:
    print(f"{repr(caso):<45} -> {repr(replacer.replace_synonyms(caso))}")

# %%
# Caso de valor no-string (ej. NaN representado como float)
print(f"Entrada no-str (None)  -> {repr(replacer.replace_synonyms(None))}")
print(f"Entrada no-str (float) -> {repr(replacer.replace_synonyms(3.1416))}")

# %% [markdown]
# ## 7.4. Prueba de `synonyms_to_dataframe` — aplicación sobre el DataFrame limpio
# Se reutiliza el `df_limpio` generado en la sección 4 con `cleaner.clean_key_column()`.

# %%
df_con_sinonimos = replacer.synonyms_to_dataframe(
    data=datos_limpios,
    column=f"{COLUMNA_CLAVE}_clean"
)

print(f"Columna nueva generada: '{COLUMNA_CLAVE}_clean_synonyms'")
df_con_sinonimos[[f"{COLUMNA_CLAVE}_clean", f"{COLUMNA_CLAVE}_clean_synonyms"]].head(10)

# %%
df_con_sinonimos.dropna(how='all').iloc[:, -2:].sort_values(by=df_con_sinonimos.columns[-2])  # Mostrar las dos últimas columnas

# %% [markdown]
# ## 7.5. Prueba de manejo de errores

# %%
# 7.5.1 Columna inexistente
print("--- Columna inexistente ---")
try:
    replacer.synonyms_to_dataframe(df_limpio, column='columna_falsa')
except ValueError as e:
    print(f"[OK] Error capturado: {e}")

# %%
# 7.5.2 build_synonyms_dict sin haber cargado el modelo
print("\n--- build_synonyms_dict sin load_model ---")
try:
    replacer_sin_modelo = SynonymReplacer()
    replacer_sin_modelo.build_synonyms_dict()
except ValueError as e:
    print(f"[OK] Error capturado: {e}")

# %%
# 7.5.3 replace_synonyms sin haber construido el diccionario
print("\n--- replace_synonyms sin build_synonyms_dict ---")
try:
    replacer_sin_dict = SynonymReplacer()
    replacer_sin_dict.replace_synonyms("un texto cualquiera")
except ValueError as e:
    print(f"[OK] Error capturado: {e}")

# %%
# 7.5.4 synonyms_to_dataframe sin haber construido el diccionario
print("\n--- synonyms_to_dataframe sin build_synonyms_dict ---")
try:
    replacer_sin_dict2 = SynonymReplacer()
    replacer_sin_dict2.synonyms_to_dataframe(df_limpio, column=f"{COLUMNA_CLAVE}_clean")
except ValueError as e:
    print(f"[OK] Error capturado: {e}")
